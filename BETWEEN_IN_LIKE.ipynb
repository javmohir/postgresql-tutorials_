# %% [markdown]
# <a href="https://colab.research.google.com/github/javmohir/malumotlarga_ishlov_berish/blob/main/BETWEEN_IN_LIKE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlite3 as sql

# %%
# !wget "https://github.com/anvarnarz/praktikum_datasets/raw/main/electricity.db"
# Out:
# --2023-09-13 01:44:27--  https://github.com/anvarnarz/praktikum_datasets/raw/main/electricity.db
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/electricity.db [following]
# --2023-09-13 01:44:27--  https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/electricity.db
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 565248 (552K) [application/octet-stream]
# Saving to: ‘electricity.db’
#
# electricity.db      100%[===================>] 552.00K  --.-KB/s    in 0.03s
#
# ...

# %%
db=sql.connect("electricity.db")
cursor=db.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
cursor.fetchall()
# Out:
# [('elect',)]

# %%
cursor.execute("PRAGMA table_info(elect);")
cursor.fetchall()
# Out:
# [(0, 'index', 'INTEGER', 0, None, 0),
#  (1, 'country', 'TEXT', 0, None, 0),
#  (2, 'code', 'TEXT', 0, None, 0),
#  (3, 'year', 'INTEGER', 0, None, 0),
#  (4, 'coal', 'REAL', 0, None, 0),
#  (5, 'gas', 'REAL', 0, None, 0),
#  (6, 'hydro', 'REAL', 0, None, 0),
#  (7, 'renewable_other', 'REAL', 0, None, 0),
#  (8, 'solar', 'REAL', 0, None, 0),
#  (9, 'oil', 'REAL', 0, None, 0),
#  (10, 'wind', 'REAL', 0, None, 0),
#  (11, 'nuclear', 'REAL', 0, None, 0)]

# %%
pd.read_sql("SELECT * FROM elect LIMIT 10", db, index_col="index")

# %%
pd.read_sql("SELECT * FROM elect LIMIT 10", db, index_col='index')
# Out:
#            country code  year  coal    gas  hydro  renewable_other  solar  \
# index
# 0      Afghanistan  AFG  2000   0.0  0.155  0.312              0.0    0.0
# 1      Afghanistan  AFG  2001   0.0  0.094  0.498              0.0    0.0
# 2      Afghanistan  AFG  2002   0.0  0.132  0.555              0.0    0.0
# 3      Afghanistan  AFG  2003   0.0  0.309  0.630              0.0    0.0
# 4      Afghanistan  AFG  2004   0.0  0.329  0.565              0.0    0.0
# 5      Afghanistan  AFG  2005   0.0  0.344  0.590              0.0    0.0
# 6      Afghanistan  AFG  2006   0.0  0.200  0.637              0.0    0.0
# 7      Afghanistan  AFG  2007   0.0  0.198  0.748              0.0    0.0
# 8      Afghanistan  AFG  2008   0.0  0.186  0.542              0.0    0.0
# 9      Afghanistan  AFG  2009   0.0  0.162  0.776              0.0    0.0
#
#        oil     wind  nuclear
# index
# 0      0.0  0.00000      0.0
# 1      0.0  0.00000      0.0
# 2      0.0  0.00000      0.0
# ...

# %%
query="SELECT DISTINCT country FROM elect"
countries=pd.read_sql(query,db)
countries.head()
# Out:
#           country
# 0     Afghanistan
# 1          Africa
# 2         Albania
# 3         Algeria
# 4  American Samoa

# %%
'Uzbekistan' in countries['country'].values
# Out:
# True

# %%
query = "SELECT * FROM elect WHERE country='Uzbekistan'"
dfuz = pd.read_sql(query,db)
dfuz.head()

# %%
query="SELECT * FROM elect WHERE country='Uzbekistan';"
dfuz=pd.read_sql(query,db)
dfuz
# Out:
#     index     country code  year       coal        gas     hydro  \
# 0    5964  Uzbekistan  UZB  2000  11.602405  25.523451  5.817000
# 1    5965  Uzbekistan  UZB  2001  11.766320  25.884038  5.899000
# 2    5966  Uzbekistan  UZB  2002  12.214374  26.869686  6.124000
# 3    5967  Uzbekistan  UZB  2003  11.833513  26.031852  7.544000
# 4    5968  Uzbekistan  UZB  2004  11.595776  25.508869  8.920000
# 5    5969  Uzbekistan  UZB  2005  11.490919  25.278199  8.838000
# 6    5970  Uzbekistan  UZB  2006  11.827788  26.019258  4.653000
# 7    5971  Uzbekistan  UZB  2007  12.051665  26.511751  4.610000
# 8    5972  Uzbekistan  UZB  2008  10.774273  23.701692  4.443000
# 9    5973  Uzbekistan  UZB  2009   9.084625  28.017530  6.418000
# 10   5974  Uzbekistan  UZB  2010   9.792027  30.199200  8.110000
# 11   5975  Uzbekistan  UZB  2011  10.534094  32.487781  5.646000
# 12   5976  Uzbekistan  UZB  2012  10.365016  31.966333  6.586000
# ...

# %%
query="SELECT country, year, coal, gas, hydro, solar, oil FROM elect WHERE country='Uzbekistan' AND year>2010"
dfu=pd.read_sql(query,db)
dfu
# Out:
#       country  year       coal        gas     hydro     solar       oil
# 0  Uzbekistan  2011  10.534094  32.487781  5.646000  0.000000  1.253064
# 1  Uzbekistan  2012  10.365016  31.966333  6.586000  0.000000  1.232952
# 2  Uzbekistan  2013  10.939346  33.737603  5.647000  0.001996  1.301270
# 3  Uzbekistan  2014  11.112674  34.272157  6.014000  0.002046  1.321888
# 4  Uzbekistan  2015  10.519789  35.780629  6.998000  0.002176  1.251363
# 5  Uzbekistan  2016  10.783891  36.678911  7.254000  0.004643  1.282778
# 6  Uzbekistan  2017  10.998707  37.409561  8.343000  0.006290  1.308332
# 7  Uzbekistan  2018  11.853192  40.315893  5.838030  0.006827  1.409975
# 8  Uzbekistan  2019  12.297660  41.827647  5.451373  0.006827  1.462846

# %% [markdown]
# BETWEEN yordamida filtrlash
# Between so'zi ingliz tildan oraliqda deb tarjima qilinadi. Bu operator yordamida ma'lum oraliqdagi qiymatlarni ajratib olishimiz mumkin.
#
# Misol uchu, kelin O'zbekiston uchun 2010 va 2021 oraliqdagi ma'lumotlarni chaqirib olamiz.

# %%
query="SELECT country, year, coal, gas, hydro, solar, oil FROM elect WHERE country='Uzbekistan' AND year BETWEEN 2010 AND 2019"
pd.read_sql(query,db)
# Out:
#       country  year       coal        gas     hydro     solar       oil
# 0  Uzbekistan  2010   9.792027  30.199200  8.110000  0.000000  1.164793
# 1  Uzbekistan  2011  10.534094  32.487781  5.646000  0.000000  1.253064
# 2  Uzbekistan  2012  10.365016  31.966333  6.586000  0.000000  1.232952
# 3  Uzbekistan  2013  10.939346  33.737603  5.647000  0.001996  1.301270
# 4  Uzbekistan  2014  11.112674  34.272157  6.014000  0.002046  1.321888
# 5  Uzbekistan  2015  10.519789  35.780629  6.998000  0.002176  1.251363
# 6  Uzbekistan  2016  10.783891  36.678911  7.254000  0.004643  1.282778
# 7  Uzbekistan  2017  10.998707  37.409561  8.343000  0.006290  1.308332
# 8  Uzbekistan  2018  11.853192  40.315893  5.838030  0.006827  1.409975
# 9  Uzbekistan  2019  12.297660  41.827647  5.451373  0.006827  1.462846

# %% [markdown]
# IN yordamida filterlashda aniq qiymatlarni ko'rsatishimiz mumkin. Quyidagi misolda aynan 1990,1995,2000,2005,2010-yillardagi qiymatlarni ajratib olamiz.

# %%
query="SELECT country, year, coal, gas, hydro, solar, oil FROM elect WHERE country='Uzbekistan' AND year IN (2015,2016,2017,2018)"
pd.read_sql(query,db)
# Out:
#       country  year       coal        gas    hydro     solar       oil
# 0  Uzbekistan  2015  10.519789  35.780629  6.99800  0.002176  1.251363
# 1  Uzbekistan  2016  10.783891  36.678911  7.25400  0.004643  1.282778
# 2  Uzbekistan  2017  10.998707  37.409561  8.34300  0.006290  1.308332
# 3  Uzbekistan  2018  11.853192  40.315893  5.83803  0.006827  1.409975

# %% [markdown]
# LIKE
# LIKE yordamida ustun orasidan berilgan matnga o'xshash qiymatlarni topish mumkin. Qidiruv matnida % yoki _ belgilari ishlatilishi mumkin.
#
# % - bir nechta belgini anglatadi, masalan '%stan' matni stan so'zi bilan tugaydigan barcha qiymatlarni topadi.
# _ - bitta belgini anglatadi, misol uchun _tol matni 4 harfdan iborat tol bilan tugaydian so'zlarni topadi (stol)
# Quyida stan bilan tugaydigan barcha davlatlar uchun 2019,2020,2021-yillardagi ma'lumotlarni olamiz

# %%
query = "SELECT * FROM elect WHERE country LIKE '%stan' AND year IN (2019, 2020, 2021)"
pd.read_sql(query, db)

# %%
query="SELECT * FROM elect WHERE country LIKE '%stan' AND year IN (2016,2017,2018) "
pd.read_sql(query, db)
# Out:
#     index       country code  year       coal        gas     hydro  \
# 0      16   Afghanistan  AFG  2016   0.000000   0.150000   1.02500
# 1      17   Afghanistan  AFG  2017   0.000000   0.168000   1.05000
# 2      18   Afghanistan  AFG  2018   0.000000   0.150000   0.92800
# 3    2844    Kazakhstan  KAZ  2016  57.936060  18.186192  11.50500
# 4    2845    Kazakhstan  KAZ  2017  66.816140  18.444680  11.09800
# 5    2846    Kazakhstan  KAZ  2018  71.321849  18.521239  10.29105
# 6    2960    Kyrgyzstan  KGZ  2016   1.547147   0.000000  11.37900
# 7    2961    Kyrgyzstan  KGZ  2017   1.147234   0.000000  14.06100
# 8    2962    Kyrgyzstan  KGZ  2018   1.056225   0.000000  14.17482
# 9    4300      Pakistan  PAK  2016   1.464795  27.860409  31.86100
# 10   4301      Pakistan  PAK  2017   2.027006  30.437095  27.64600
# 11   4302      Pakistan  PAK  2018  17.041587  27.192197  37.00620
# 12   5492    Tajikistan  TJK  2016   0.000000   0.000000  16.46600
# ...

# %%
query = "SELECT * FROM elect WHERE code LIKE 'A__' AND year=2019"
pd.read_sql(query, db)
# Out:
#     index               country code  year        coal         gas     hydro  \
# 0      19           Afghanistan  AFG  2019    0.000000    0.152000   0.84000
# 1      74               Albania  ALB  2019    0.000000    0.000000   5.15394
# 2     129        American Samoa  ASM  2019    0.000000    0.000000   0.00000
# 3     149                Angola  AGO  2019    0.000000    1.283610   9.84988
# 4     169            Antarctica  ATA  2019    0.000000    0.000000   0.00000
# 5     189   Antigua and Barbuda  ATG  2019    0.000000    0.000000   0.00000
# 6     224             Argentina  ARG  2019    0.740682   85.786609  27.33489
# 7     245               Armenia  ARM  2019    0.000000    2.864180   2.34729
# 8     265                 Aruba  ABW  2019    0.000000    0.000000   0.00000
# 9     335             Australia  AUS  2019  142.017830   51.638469  15.53805
# 10    356               Austria  AUT  2019    1.633164   11.617832  41.63827
# ...
