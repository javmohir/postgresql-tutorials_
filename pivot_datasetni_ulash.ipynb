# %% [markdown]
# <a href="https://colab.research.google.com/github/javmohir/malumotlarga_ishlov_berish/blob/main/pivot_datasetni_ulash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Uzun datasetdan Keng dataset olish (pivot)

# %%
# !wget https://github.com/MansurCompAI/Practicum_Datasets/blob/master/data_pivot.csv
# Out:
# --2023-09-25 04:16:31--  https://github.com/MansurCompAI/Practicum_Datasets/blob/master/data_pivot.csv
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35738 (35K) [text/plain]
# Saving to: ‘data_pivot.csv’
#
# data_pivot.csv      100%[===================>]  34.90K  --.-KB/s    in 0.04s
#
# 2023-09-25 04:16:31 (776 KB/s) - ‘data_pivot.csv’ saved [35738/35738]

# %%
# !git clone https://github.com/MansurCompAI/Practicum_Datasets.git
# Out:
# Cloning into 'Practicum_Datasets'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 60 (delta 17), reused 16 (delta 1), pack-reused 0
# Receiving objects: 100% (60/60), 20.24 MiB | 16.49 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
data=pd.read_csv("/content/Practicum_Datasets/data_pivot.csv")
data
# Out:
#                               date     item      value
# 0    1959-03-31 23:59:59.999999999  realgdp   2710.349
# 1    1959-03-31 23:59:59.999999999     infl      0.000
# 2    1959-03-31 23:59:59.999999999    unemp      5.800
# 3    1959-06-30 23:59:59.999999999  realgdp   2778.801
# 4    1959-06-30 23:59:59.999999999     infl      2.340
# ..                             ...      ...        ...
# 604  2009-06-30 23:59:59.999999999     infl      3.370
# 605  2009-06-30 23:59:59.999999999    unemp      9.200
# 606  2009-09-30 23:59:59.999999999  realgdp  12990.341
# 607  2009-09-30 23:59:59.999999999     infl      3.560
# 608  2009-09-30 23:59:59.999999999    unemp      9.600
#
# [609 rows x 3 columns]

# %%
piv_data=data.pivot('date','item','value')
piv_data
# Out:
# <ipython-input-5-9d5ba2de1e63>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   piv_data=data.pivot('date','item','value')
# item                           infl    realgdp  unemp
# date
# 1959-03-31 23:59:59.999999999  0.00   2710.349    5.8
# 1959-06-30 23:59:59.999999999  2.34   2778.801    5.1
# 1959-09-30 23:59:59.999999999  2.74   2775.488    5.3
# 1959-12-31 23:59:59.999999999  0.27   2785.204    5.6
# 1960-03-31 23:59:59.999999999  2.31   2847.699    5.2
# ...                             ...        ...    ...
# 2008-09-30 23:59:59.999999999 -3.16  13324.600    6.0
# 2008-12-31 23:59:59.999999999 -8.79  13141.920    6.9
# 2009-03-31 23:59:59.999999999  0.94  12925.410    8.1
# 2009-06-30 23:59:59.999999999  3.37  12901.504    9.2
# 2009-09-30 23:59:59.999999999  3.56  12990.341    9.6
#
# [203 rows x 3 columns]

# %%
data['value2']=np.random.randn(len(data))
data
# Out:
#                               date     item      value    value2
# 0    1959-03-31 23:59:59.999999999  realgdp   2710.349  1.619853
# 1    1959-03-31 23:59:59.999999999     infl      0.000 -1.022238
# 2    1959-03-31 23:59:59.999999999    unemp      5.800  1.370472
# 3    1959-06-30 23:59:59.999999999  realgdp   2778.801  1.269297
# 4    1959-06-30 23:59:59.999999999     infl      2.340 -0.567255
# ..                             ...      ...        ...       ...
# 604  2009-06-30 23:59:59.999999999     infl      3.370 -0.884770
# 605  2009-06-30 23:59:59.999999999    unemp      9.200  1.643111
# 606  2009-09-30 23:59:59.999999999  realgdp  12990.341 -0.322481
# 607  2009-09-30 23:59:59.999999999     infl      3.560  0.609281
# 608  2009-09-30 23:59:59.999999999    unemp      9.600  0.828672
#
# [609 rows x 4 columns]

# %%
pivid_dat=data.pivot('date','item')
pivid_dat
# Out:
# <ipython-input-7-566d566b4930>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   pivid_dat=data.pivot('date','item')
#                               value                     value2            \
# item                           infl    realgdp unemp      infl   realgdp
# date
# 1959-03-31 23:59:59.999999999  0.00   2710.349   5.8 -1.022238  1.619853
# 1959-06-30 23:59:59.999999999  2.34   2778.801   5.1 -0.567255  1.269297
# 1959-09-30 23:59:59.999999999  2.74   2775.488   5.3  0.422801 -2.057339
# 1959-12-31 23:59:59.999999999  0.27   2785.204   5.6 -0.466893 -0.925330
# 1960-03-31 23:59:59.999999999  2.31   2847.699   5.2  2.479975  0.204383
# ...                             ...        ...   ...       ...       ...
# 2008-09-30 23:59:59.999999999 -3.16  13324.600   6.0 -0.330971 -1.131830
# 2008-12-31 23:59:59.999999999 -8.79  13141.920   6.9  0.489168  0.605770
# ...

# %%
pivid_dat['value'].head(10)
# Out:
# item                           infl   realgdp  unemp
# date
# 1959-03-31 23:59:59.999999999  0.00  2710.349    5.8
# 1959-06-30 23:59:59.999999999  2.34  2778.801    5.1
# 1959-09-30 23:59:59.999999999  2.74  2775.488    5.3
# 1959-12-31 23:59:59.999999999  0.27  2785.204    5.6
# 1960-03-31 23:59:59.999999999  2.31  2847.699    5.2
# 1960-06-30 23:59:59.999999999  0.14  2834.390    5.2
# 1960-09-30 23:59:59.999999999  2.70  2839.022    5.6
# 1960-12-31 23:59:59.999999999  1.21  2802.616    6.3
# 1961-03-31 23:59:59.999999999 -0.40  2819.264    6.8
# 1961-06-30 23:59:59.999999999  1.47  2872.005    7.0

# %%
pivid_dat['value2'].head(10)
# Out:
# item                               infl   realgdp     unemp
# date
# 1959-03-31 23:59:59.999999999 -1.022238  1.619853  1.370472
# 1959-06-30 23:59:59.999999999 -0.567255  1.269297  1.337122
# 1959-09-30 23:59:59.999999999  0.422801 -2.057339 -0.138822
# 1959-12-31 23:59:59.999999999 -0.466893 -0.925330 -0.109834
# 1960-03-31 23:59:59.999999999  2.479975  0.204383  1.981963
# 1960-06-30 23:59:59.999999999  0.361755  1.332619  1.944868
# 1960-09-30 23:59:59.999999999  1.637239  0.332803 -0.733892
# 1960-12-31 23:59:59.999999999  2.286765 -0.630257 -0.102077
# 1961-03-31 23:59:59.999999999 -0.590288 -0.637701  1.321851
# 1961-06-30 23:59:59.999999999  1.887383  0.746586 -0.893563
